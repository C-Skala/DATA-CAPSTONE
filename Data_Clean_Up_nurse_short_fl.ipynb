# %%
import pandas as pd

# %%
df = pd.read_csv("Nurse_Shortage.csv")

df
# Out:
# C:\Users\cjska\AppData\Local\Temp\ipykernel_2480\730772102.py:1: DtypeWarning: Columns (8,16,18,22,26,28,34,54,61,97,101,102,103,104,113,131) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Nurse_Shortage.csv")
#       state        date  critical_staffing_shortage_today_yes  \
# 0        RI  2021/02/19                                     4
# 1        MA  2021/01/30                                    10
# 2        NE  2021/01/30                                     8
# 3        MA  2021/01/29                                    10
# 4        UT  2021/01/29                                     1
# ...     ...         ...                                   ...
# 58001    IL  2021/08/20                                    11
# 58002    TX  2021/04/19                                   105
# 58003    LA  2021/04/20                                    42
# 58004    HI  2021/07/17                                     2
# ...

# %%
df.duplicated().sort_values()
# Out:
# 0        False
# 38663    False
# 38664    False
# 38665    False
# 38666    False
#          ...
# 19340    False
# 19341    False
# 19342    False
# 19316    False
# 58005    False
# Length: 58006, dtype: bool

# %%
fldf = df[(df['state'] == 'FL')]

fldf.head()
# Out:
#     state        date  critical_staffing_shortage_today_yes  \
# 76     FL  2020/07/10                                     0
# 884    FL  2020/08/10                                     9
# 900    FL  2020/12/06                                    10
# 928    FL  2020/10/25                                    14
# 936    FL  2020/07/20                                    18
#
#      critical_staffing_shortage_today_no  \
# 76                                     0
# 884                                   23
# 900                                  252
# 928                                  248
# 936                                   25
#
#      critical_staffing_shortage_today_not_reported  \
# 76                                             269
# 884                                            226
# 900                                              6
# 928                                              6
# 936                                            224
#
# ...

# %%
fldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1069 entries, 76 to 57893
# Columns: 135 entries, state to total_staffed_pediatric_icu_beds_coverage
# dtypes: float64(40), int64(56), object(39)
# memory usage: 1.1+ MB

# %%
fldf.to_csv('florida_nurse_shortage.csv', encoding='utf-8')
