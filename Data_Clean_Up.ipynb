# %%
import pandas as pd

# %%
df = pd.read_csv("Covid_Cases.csv", index_col = 'hospital_pk')

df
# Out:
# C:\Users\cjska\AppData\Local\Temp\ipykernel_12420\3497204595.py:1: DtypeWarning: Columns (0,3,12,28,29,30,43,44,45,48,49,50,72,84,95,102,103,104,105,106,107,112,114,115,116,117,118,125,127) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Covid_Cases.csv", index_col = 'hospital_pk')
#             collection_week state       ccn  \
# hospital_pk
# 052052           2020/05/29    CA    052052
# 070038           2020/04/24    CT    070038
# 100034           2020/05/01    FL    100034
# 100069           2020/05/15    FL    100069
# 100070           2020/04/24    FL    100070
# ...                     ...   ...       ...
# 330058           2022/12/30    NY  330058.0
# 360051           2022/04/15    OH  360051.0
# 453314           2021/12/24    TX  453314.0
# 280065           2021/01/08    NE  280065.0
# 420030           2022/06/10    SC  420030.0
#
#                                           hospital_name  \
# hospital_pk
# 052052                       KINDRED HOSPITAL RIVERSIDE
# 070038                      CONNECTICUT HOSPICE INC,THE
# 100034       MOUNT SINAI MEDICAL CENTER OF FLORIDA, INC
# 100069                         ADVENTHEALTH CARROLLWOOD
# 100070                         SHOREPOINT HEALTH VENICE
# ...                                                 ...
# 330058                          GENEVA GENERAL HOSPITAL
# 360051                            MIAMI VALLEY HOSPITAL
# 453314        TEXAS SCOTTISH RITE HOSPITAL FOR CHILDREN
# 280065                              GREAT PLAINS HEALTH
# 420030                          COLLETON MEDICAL CENTER
#
#                                address          city      zip  \
# hospital_pk
# 052052       2224 MEDICAL CENTER DRIVE        PERRIS  92571.0
# 070038           100 DOUBLE BEACH ROAD      BRANFORD   6405.0
# 100034                   4300 ALTON RD   MIAMI BEACH  33140.0
# 100069           7171 N DALE MABRY HWY         TAMPA  33614.0
# 100070                  540 THE RIALTO        VENICE  34285.0
# ...                                ...           ...      ...
# 330058           196 -198 NORTH STREET        GENEVA  14456.0
# 360051              ONE WYOMING STREET        DAYTON  45409.0
# 453314             2222 WELBORN STREET        DALLAS  75219.0
# 280065               601 WEST LEOTA ST  NORTH PLATTE  69101.0
# 420030         501 ROBERTSON BOULEVARD    WALTERBORO  29488.0
#
#                 hospital_subtype  fips_code  is_metro_micro  ...  \
# hospital_pk                                                  ...
# 052052                 Long Term     6065.0            True  ...
# 070038                Short Term     9009.0            True  ...
# 100034                Short Term    12086.0            True  ...
# 100069                Short Term    12057.0            True  ...
# 100070                Short Term    12115.0            True  ...
# ...                          ...        ...             ...  ...
# 330058                Short Term    36069.0            True  ...
# 360051                Short Term    39113.0            True  ...
# 453314       Childrens Hospitals    48113.0            True  ...
# 280065                Short Term    31111.0            True  ...
# 420030                Short Term    45029.0           False  ...
#
#             previous_day_admission_pediatric_covid_confirmed_unknown_7_day_sum  \
# hospital_pk
# 052052                                                     NaN
# 070038                                                     NaN
# 100034                                                     NaN
# 100069                                                     NaN
# 100070                                                     NaN
# ...                                                        ...
# 330058                                                     0.0
# 360051                                                     0.0
# 453314                                                     NaN
# 280065                                                     NaN
# 420030                                                     0.0
#
#             staffed_icu_pediatric_patients_confirmed_covid_7_day_avg  \
# hospital_pk
# 052052                                                     NaN
# 070038                                                     NaN
# 100034                                                     NaN
# 100069                                                     NaN
# 100070                                                     NaN
# ...                                                        ...
# 330058                                                       0
# 360051                                                       0
# 453314                                                     NaN
# 280065                                                     NaN
# 420030                                                       0
#
#             staffed_icu_pediatric_patients_confirmed_covid_7_day_coverage  \
# hospital_pk
# 052052                                                       0
# 070038                                                       0
# 100034                                                       0
# 100069                                                       0
# 100070                                                       0
# ...                                                        ...
# 330058                                                       7
# 360051                                                       7
# 453314                                                       0
# 280065                                                       0
# 420030                                                       7
#
#             staffed_icu_pediatric_patients_confirmed_covid_7_day_sum  \
# hospital_pk
# 052052                                                     NaN
# 070038                                                     NaN
# 100034                                                     NaN
# 100069                                                     NaN
# 100070                                                     NaN
# ...                                                        ...
# 330058                                                       0
# 360051                                                       0
# 453314                                                     NaN
# 280065                                                     NaN
# 420030                                                       0
#
#             staffed_pediatric_icu_bed_occupancy_7_day_avg  \
# hospital_pk
# 052052                                                NaN
# 070038                                                NaN
# 100034                                                NaN
# 100069                                                NaN
# 100070                                                NaN
# ...                                                   ...
# 330058                                                  0
# 360051                                                  0
# 453314                                                  0
# 280065                                                NaN
# 420030                                                  0
#
#             staffed_pediatric_icu_bed_occupancy_7_day_coverage  \
# hospital_pk
# 052052                                                       0
# 070038                                                       0
# 100034                                                       0
# 100069                                                       0
# 100070                                                       0
# ...                                                        ...
# 330058                                                       7
# 360051                                                       7
# 453314                                                       7
# 280065                                                       0
# 420030                                                       7
#
#             staffed_pediatric_icu_bed_occupancy_7_day_sum  \
# hospital_pk
# 052052                                                NaN
# 070038                                                NaN
# 100034                                                NaN
# 100069                                                NaN
# 100070                                                NaN
# ...                                                   ...
# 330058                                                  0
# 360051                                                  0
# 453314                                                  0
# 280065                                                NaN
# 420030                                                  0
#
#             total_staffed_pediatric_icu_beds_7_day_avg  \
# hospital_pk
# 052052                                             NaN
# 070038                                             NaN
# 100034                                             NaN
# 100069                                             NaN
# 100070                                             NaN
# ...                                                ...
# 330058                                               0
# 360051                                               0
# 453314                                               0
# 280065                                             NaN
# 420030                                               0
#
#             total_staffed_pediatric_icu_beds_7_day_coverage  \
# hospital_pk
# 052052                                                    0
# 070038                                                    0
# 100034                                                    0
# 100069                                                    0
# 100070                                                    0
# ...                                                     ...
# 330058                                                    7
# 360051                                                    7
# 453314                                                    7
# 280065                                                    0
# 420030                                                    7
#
#             total_staffed_pediatric_icu_beds_7_day_sum
# hospital_pk
# 052052                                             NaN
# 070038                                             NaN
# 100034                                             NaN
# 100069                                             NaN
# 100070                                             NaN
# ...                                                ...
# 330058                                               0
# 360051                                               0
# 453314                                               0
# 280065                                             NaN
# 420030                                               0
#
# [742253 rows x 127 columns]

# %%
df.duplicated().sort_values()
# Out:
# hospital_pk
# 052052    False
# 050076    False
# 150088    False
# 050305    False
# 171371    False
#           ...
# 440009    False
# 520089    False
# 450403    False
# 441313    False
# 420030    False
# Length: 742253, dtype: bool

# %%
dropedDF = df.drop(['ccn', 'address', 'city', 'zip', 'fips_code'], axis=1)

dropedDF.head()
# Out:
#             collection_week state                               hospital_name  \
# hospital_pk
# 052052           2020/05/29    CA                  KINDRED HOSPITAL RIVERSIDE
# 070038           2020/04/24    CT                 CONNECTICUT HOSPICE INC,THE
# 100034           2020/05/01    FL  MOUNT SINAI MEDICAL CENTER OF FLORIDA, INC
# 100069           2020/05/15    FL                    ADVENTHEALTH CARROLLWOOD
# 100070           2020/04/24    FL                    SHOREPOINT HEALTH VENICE
#
#             hospital_subtype  is_metro_micro total_beds_7_day_avg  \
# hospital_pk
# 052052             Long Term            True                   40
# 070038            Short Term            True                  NaN
# 100034            Short Term            True                  NaN
# 100069            Short Term            True                382.3
# 100070            Short Term            True                  248
#
#             all_adult_hospital_beds_7_day_avg  \
# hospital_pk
# 052052                                    NaN
# 070038                                    NaN
# 100034                                    NaN
# 100069                                    NaN
# 100070                                    NaN
#
#             all_adult_hospital_inpatient_beds_7_day_avg  \
# hospital_pk
# 052052                                              NaN
# 070038                                              NaN
# 100034                                              NaN
# 100069                                              NaN
# 100070                                              NaN
#
#             inpatient_beds_used_7_day_avg  \
# hospital_pk
# 052052                               38.3
# 070038                                NaN
# 100034                                NaN
# 100069                               60.3
# 100070                               76.6
#
#             all_adult_hospital_inpatient_bed_occupied_7_day_avg  ...  \
# hospital_pk                                                      ...
# 052052                                                     NaN   ...
# 070038                                                     NaN   ...
# 100034                                                     NaN   ...
# 100069                                                     NaN   ...
# 100070                                                     NaN   ...
#
#             previous_day_admission_pediatric_covid_confirmed_unknown_7_day_sum  \
# hospital_pk
# 052052                                                     NaN
# 070038                                                     NaN
# 100034                                                     NaN
# 100069                                                     NaN
# 100070                                                     NaN
#
#             staffed_icu_pediatric_patients_confirmed_covid_7_day_avg  \
# hospital_pk
# 052052                                                     NaN
# 070038                                                     NaN
# 100034                                                     NaN
# 100069                                                     NaN
# 100070                                                     NaN
#
#             staffed_icu_pediatric_patients_confirmed_covid_7_day_coverage  \
# hospital_pk
# 052052                                                       0
# 070038                                                       0
# 100034                                                       0
# 100069                                                       0
# 100070                                                       0
#
#             staffed_icu_pediatric_patients_confirmed_covid_7_day_sum  \
# hospital_pk
# 052052                                                     NaN
# 070038                                                     NaN
# 100034                                                     NaN
# 100069                                                     NaN
# 100070                                                     NaN
#
#             staffed_pediatric_icu_bed_occupancy_7_day_avg  \
# hospital_pk
# 052052                                                NaN
# 070038                                                NaN
# 100034                                                NaN
# 100069                                                NaN
# 100070                                                NaN
#
#             staffed_pediatric_icu_bed_occupancy_7_day_coverage  \
# hospital_pk
# 052052                                                       0
# 070038                                                       0
# 100034                                                       0
# 100069                                                       0
# 100070                                                       0
#
#             staffed_pediatric_icu_bed_occupancy_7_day_sum  \
# hospital_pk
# 052052                                                NaN
# 070038                                                NaN
# 100034                                                NaN
# 100069                                                NaN
# 100070                                                NaN
#
#             total_staffed_pediatric_icu_beds_7_day_avg  \
# hospital_pk
# 052052                                             NaN
# 070038                                             NaN
# 100034                                             NaN
# 100069                                             NaN
# 100070                                             NaN
#
#             total_staffed_pediatric_icu_beds_7_day_coverage  \
# hospital_pk
# 052052                                                    0
# 070038                                                    0
# 100034                                                    0
# 100069                                                    0
# 100070                                                    0
#
#             total_staffed_pediatric_icu_beds_7_day_sum
# hospital_pk
# 052052                                             NaN
# 070038                                             NaN
# 100034                                             NaN
# 100069                                             NaN
# 100070                                             NaN
#
# [5 rows x 122 columns]

# %%
fldf = dropedDF[(dropedDF['state'] == 'FL')]

fldf.head()
# Out:
#             collection_week state                               hospital_name  \
# hospital_pk
# 100034           2020/05/01    FL  MOUNT SINAI MEDICAL CENTER OF FLORIDA, INC
# 100069           2020/05/15    FL                    ADVENTHEALTH CARROLLWOOD
# 100070           2020/04/24    FL                    SHOREPOINT HEALTH VENICE
# 100156           2020/06/19    FL              HCA FLORIDA LAKE CITY HOSPITAL
# 100269           2020/06/26    FL             HCA FLORIDA PALMS WEST HOSPITAL
#
#             hospital_subtype  is_metro_micro total_beds_7_day_avg  \
# hospital_pk
# 100034            Short Term            True                  NaN
# 100069            Short Term            True                382.3
# 100070            Short Term            True                  248
# 100156            Short Term            True                  NaN
# 100269            Short Term            True                  NaN
#
#             all_adult_hospital_beds_7_day_avg  \
# hospital_pk
# 100034                                    NaN
# 100069                                    NaN
# 100070                                    NaN
# 100156                                    NaN
# 100269                                    NaN
#
#             all_adult_hospital_inpatient_beds_7_day_avg  \
# hospital_pk
# 100034                                              NaN
# 100069                                              NaN
# 100070                                              NaN
# 100156                                              NaN
# 100269                                              NaN
#
#             inpatient_beds_used_7_day_avg  \
# hospital_pk
# 100034                                NaN
# 100069                               60.3
# 100070                               76.6
# 100156                                NaN
# 100269                                NaN
#
#             all_adult_hospital_inpatient_bed_occupied_7_day_avg  ...  \
# hospital_pk                                                      ...
# 100034                                                     NaN   ...
# 100069                                                     NaN   ...
# 100070                                                     NaN   ...
# 100156                                                     NaN   ...
# 100269                                                     NaN   ...
#
#             previous_day_admission_pediatric_covid_confirmed_unknown_7_day_sum  \
# hospital_pk
# 100034                                                     NaN
# 100069                                                     NaN
# 100070                                                     NaN
# 100156                                                     NaN
# 100269                                                     NaN
#
#             staffed_icu_pediatric_patients_confirmed_covid_7_day_avg  \
# hospital_pk
# 100034                                                     NaN
# 100069                                                     NaN
# 100070                                                     NaN
# 100156                                                     NaN
# 100269                                                     NaN
#
#             staffed_icu_pediatric_patients_confirmed_covid_7_day_coverage  \
# hospital_pk
# 100034                                                       0
# 100069                                                       0
# 100070                                                       0
# 100156                                                       0
# 100269                                                       0
#
#             staffed_icu_pediatric_patients_confirmed_covid_7_day_sum  \
# hospital_pk
# 100034                                                     NaN
# 100069                                                     NaN
# 100070                                                     NaN
# 100156                                                     NaN
# 100269                                                     NaN
#
#             staffed_pediatric_icu_bed_occupancy_7_day_avg  \
# hospital_pk
# 100034                                                NaN
# 100069                                                NaN
# 100070                                                NaN
# 100156                                                NaN
# 100269                                                NaN
#
#             staffed_pediatric_icu_bed_occupancy_7_day_coverage  \
# hospital_pk
# 100034                                                       0
# 100069                                                       0
# 100070                                                       0
# 100156                                                       0
# 100269                                                       0
#
#             staffed_pediatric_icu_bed_occupancy_7_day_sum  \
# hospital_pk
# 100034                                                NaN
# 100069                                                NaN
# 100070                                                NaN
# 100156                                                NaN
# 100269                                                NaN
#
#             total_staffed_pediatric_icu_beds_7_day_avg  \
# hospital_pk
# 100034                                             NaN
# 100069                                             NaN
# 100070                                             NaN
# 100156                                             NaN
# 100269                                             NaN
#
#             total_staffed_pediatric_icu_beds_7_day_coverage  \
# hospital_pk
# 100034                                                    0
# 100069                                                    0
# 100070                                                    0
# 100156                                                    0
# 100269                                                    0
#
#             total_staffed_pediatric_icu_beds_7_day_sum
# hospital_pk
# 100034                                             NaN
# 100069                                             NaN
# 100070                                             NaN
# 100156                                             NaN
# 100269                                             NaN
#
# [5 rows x 122 columns]

# %%
fldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30970 entries, 100034 to 100099
# Columns: 122 entries, collection_week to total_staffed_pediatric_icu_beds_7_day_sum
# dtypes: bool(2), int64(29), object(91)
# memory usage: 28.6+ MB

# %%
mmfldf = dropedDF[(dropedDF['hospital_name'] == 'MANATEE MEMORIAL HOSPITAL')]

mmfldf.head()
# Out:
#             collection_week state              hospital_name hospital_subtype  \
# hospital_pk
# 100035           2020/05/22    FL  MANATEE MEMORIAL HOSPITAL       Short Term
# 100035           2020/04/17    FL  MANATEE MEMORIAL HOSPITAL       Short Term
# 100035           2020/06/19    FL  MANATEE MEMORIAL HOSPITAL       Short Term
# 100035           2020/04/03    FL  MANATEE MEMORIAL HOSPITAL       Short Term
# 100035           2020/10/23    FL  MANATEE MEMORIAL HOSPITAL       Short Term
#
#              is_metro_micro total_beds_7_day_avg  \
# hospital_pk
# 100035                 True                  NaN
# 100035                 True                  NaN
# 100035                 True                  NaN
# 100035                 True                  NaN
# 100035                 True                332.9
#
#             all_adult_hospital_beds_7_day_avg  \
# hospital_pk
# 100035                                    NaN
# 100035                                    NaN
# 100035                                    NaN
# 100035                                    NaN
# 100035                                  298.4
#
#             all_adult_hospital_inpatient_beds_7_day_avg  \
# hospital_pk
# 100035                                              NaN
# 100035                                              NaN
# 100035                                              NaN
# 100035                                              NaN
# 100035                                            298.4
#
#             inpatient_beds_used_7_day_avg  \
# hospital_pk
# 100035                                NaN
# 100035                                NaN
# 100035                                NaN
# 100035                                NaN
# 100035                              275.4
#
#             all_adult_hospital_inpatient_bed_occupied_7_day_avg  ...  \
# hospital_pk                                                      ...
# 100035                                                     NaN   ...
# 100035                                                     NaN   ...
# 100035                                                     NaN   ...
# 100035                                                     NaN   ...
# 100035                                                     266   ...
#
#             previous_day_admission_pediatric_covid_confirmed_unknown_7_day_sum  \
# hospital_pk
# 100035                                                     NaN
# 100035                                                     NaN
# 100035                                                     NaN
# 100035                                                     NaN
# 100035                                                     NaN
#
#             staffed_icu_pediatric_patients_confirmed_covid_7_day_avg  \
# hospital_pk
# 100035                                                     NaN
# 100035                                                     NaN
# 100035                                                     NaN
# 100035                                                     NaN
# 100035                                                     NaN
#
#             staffed_icu_pediatric_patients_confirmed_covid_7_day_coverage  \
# hospital_pk
# 100035                                                       0
# 100035                                                       0
# 100035                                                       0
# 100035                                                       0
# 100035                                                       0
#
#             staffed_icu_pediatric_patients_confirmed_covid_7_day_sum  \
# hospital_pk
# 100035                                                     NaN
# 100035                                                     NaN
# 100035                                                     NaN
# 100035                                                     NaN
# 100035                                                     NaN
#
#             staffed_pediatric_icu_bed_occupancy_7_day_avg  \
# hospital_pk
# 100035                                                NaN
# 100035                                                NaN
# 100035                                                NaN
# 100035                                                NaN
# 100035                                                  4
#
#             staffed_pediatric_icu_bed_occupancy_7_day_coverage  \
# hospital_pk
# 100035                                                       0
# 100035                                                       0
# 100035                                                       0
# 100035                                                       0
# 100035                                                       2
#
#             staffed_pediatric_icu_bed_occupancy_7_day_sum  \
# hospital_pk
# 100035                                                NaN
# 100035                                                NaN
# 100035                                                NaN
# 100035                                                NaN
# 100035                                                  8
#
#             total_staffed_pediatric_icu_beds_7_day_avg  \
# hospital_pk
# 100035                                             NaN
# 100035                                             NaN
# 100035                                             NaN
# 100035                                             NaN
# 100035                                        -999,999
#
#             total_staffed_pediatric_icu_beds_7_day_coverage  \
# hospital_pk
# 100035                                                    0
# 100035                                                    0
# 100035                                                    0
# 100035                                                    0
# 100035                                                    2
#
#             total_staffed_pediatric_icu_beds_7_day_sum
# hospital_pk
# 100035                                             NaN
# 100035                                             NaN
# 100035                                             NaN
# 100035                                             NaN
# 100035                                               6
#
# [5 rows x 122 columns]

# %%
## fldf.to_csv('florida_hospitals.csv', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 fldf.to_csv('florida_hospitals.csv', encoding='utf-8')
#
# File c:\Users\cjska\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\cjska\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File c:\Users\cjska\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\cjska\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\cjska\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File c:\Users\cjska\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'florida_hospitals.csv'

# %%
mmfldf.to_csv('florida_hospital_manatee_memorial.csv', encoding='utf-8')
